# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame(pd.read_csv('Mall Customers.csv'))
data
# Out:
#      Unnamed: 0  CustomerID  Gender  Age  Annual Income (k$)  \
# 0             0           1    Male   19                  15
# 1             1           2    Male   21                  15
# 2             2           3  Female   20                  16
# 3             3           4  Female   23                  16
# 4             4           5  Female   31                  17
# ..          ...         ...     ...  ...                 ...
# 195         195         196  Female   35                 120
# 196         196         197  Female   45                 126
# 197         197         198    Male   32                 126
# 198         198         199    Male   32                 137
# 199         199         200    Male   30                 137
#
#      Spending Score (1-100)  Label
# 0                        39      0
# 1                        81      4
# 2                         6      0
# 3                        77      4
# 4                        40      0
# ...

# %%
data.groupby(by=['Label'])[['Age','Spending Score (1-100)']].mean()
# Out:
#              Age  Spending Score (1-100)
# Label
# 0      45.217391               20.913043
# 1      32.692308               82.128205
# 2      40.324324               18.189189
# 3      43.126582               49.835443
# 4      25.272727               79.363636

# %%
plt.
# Out:
#   File "<ipython-input-4-efb1a9b93a17>", line 1
#     plt.
#         ^
# SyntaxError: invalid syntax

# %%
data.groupby(by=['Label'])[['Annual Income (k$)', 'Spending Score (1-100)']].mean()
# Out:
#        Annual Income (k$)  Spending Score (1-100)
# Label
# 0               26.304348               20.913043
# 1               86.538462               82.128205
# 2               87.432432               18.189189
# 3               54.822785               49.835443
# 4               25.727273               79.363636

# %%
data.groupby(by=['Label'])[['Annual Income (k$)', 'Spending Score (1-100)']].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Label'>

# %% [markdown]
# Kami adalah E-commerce baru, mencari kostumer pada data ini dan mempunyai beberapa label, yang mana label ini kita berusaha membuat strategi agar semua kostumer bisa setia pada E-commerce kami, berusaha membuat costumer spending score lebih dari >=49 dan jika spending score > 49 kami berusaha untuk mempertahankannya berikut beberapa strateginya.
#
# Hacktive Mall
#
# - Label 0 : Menawarkan cashback dan promo gratis ongkir
# - Label 1 : Menawarkan product high end yang bekerja sama pada product branded dan membership (loyal point ditukar voucher dll)
# - Label 2 : Menawarkan fitur baru (contoh: investasi legal), menawarkan promosi pada barang yang berkualitas dengan tujuan menarik pasar
# - Label 3 : Menawarkan fitur kemudahan pembayaran (contoh: auto debet, notifikasi yang friendly, meningkatkan opsi pembayaran) dan promosi terhadap jenis produk yang sama
# - Label 4 : Menawarkan cashback dan fitur kredit (memberikan extra cashback jika menggunakan fitur kredit)

# %%
data.groupby(by=['Label','Gender'])[['Annual Income (k$)', 'Spending Score (1-100)']].mean()
# dataCpy = pd.DataFrame(aaa).set_index('Age')
# Out:
#               Annual Income (k$)  Spending Score (1-100)
# Label Gender
# 0     Female           27.357143               21.714286
#       Male             24.666667               19.666667
# 1     Female           86.047619               81.666667
#       Male             87.111111               82.666667
# 2     Female           89.055556               23.722222
#       Male             85.894737               12.947368
# 3     Female           54.543478               49.521739
#       Male             55.212121               50.272727
# 4     Female           25.692308               80.538462
#       Male             25.777778               77.666667
