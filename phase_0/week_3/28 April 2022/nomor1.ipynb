# %% [markdown]
# 1. You have segmented your customers by using clustering algorithm and the results are stored in the labels column. What promotion strategy you’ll recommend to the marketing division?

# %%
import pandas as pd
import numpy as np

# %%
costumer = pd.read_csv('Mall Customers.csv')
costumer
# Out:
#      Unnamed: 0  CustomerID  Gender  Age  Annual Income (k$)  \
# 0             0           1    Male   19                  15
# 1             1           2    Male   21                  15
# 2             2           3  Female   20                  16
# 3             3           4  Female   23                  16
# 4             4           5  Female   31                  17
# ..          ...         ...     ...  ...                 ...
# 195         195         196  Female   35                 120
# 196         196         197  Female   45                 126
# 197         197         198    Male   32                 126
# 198         198         199    Male   32                 137
# 199         199         200    Male   30                 137
#
#      Spending Score (1-100)  Label
# 0                        39      0
# 1                        81      4
# 2                         6      0
# 3                        77      4
# 4                        40      0
# ..                      ...    ...
# 195                      79      1
# 196                      28      2
# 197                      74      1
# 198                      18      2
# 199                      83      1
#
# [200 rows x 7 columns]

# %%
costumercpy = costumer.copy

# %%
costumercpy.groupby(by=['Label'])[['Annual Income (k$)', 'Spending Score (1-100)']].mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ab5a03483aa6> in <module>
# ----> 1 costumercpy.groupby(by=['Label'])[['Annual Income (k$)', 'Spending Score (1-100)']].mean()
#
# AttributeError: 'function' object has no attribute 'groupby'
