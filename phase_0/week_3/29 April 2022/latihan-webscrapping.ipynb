# %%
# !pip install bs4
# !pip install requests
# !pip install selenium
# Out:
# Requirement already satisfied: bs4 in c:\users\enggar\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\enggar\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\enggar\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)
# Requirement already satisfied: requests in c:\users\enggar\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\enggar\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\enggar\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\enggar\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\enggar\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Collecting selenium
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# conda 4.12.0 requires ruamel_yaml_conda>=0.11.14, which is not installed.
# requests 2.24.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.9 which is incompatible.
#   Downloading selenium-4.1.3-py3-none-any.whl (968 kB)
# Collecting trio~=0.17
#   Downloading trio-0.20.0-py3-none-any.whl (359 kB)
# Collecting urllib3[secure,socks]~=1.26
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: async-generator>=1.9 in c:\users\enggar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\enggar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\enggar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\enggar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.2.2)
# Requirement already satisfied: cffi>=1.14; os_name == "nt" and implementation_name != "pypy" in c:\users\enggar\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.3)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi; extra == "secure" in c:\users\enggar\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2020.6.20)
# Requirement already satisfied: cryptography>=1.3.4; extra == "secure" in c:\users\enggar\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.1.1)
# Requirement already satisfied: pyOpenSSL>=0.14; extra == "secure" in c:\users\enggar\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (19.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6; extra == "socks" in c:\users\enggar\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pycparser in c:\users\enggar\anaconda3\lib\site-packages (from cffi>=1.14; os_name == "nt" and implementation_name != "pypy"->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: six>=1.4.1 in c:\users\enggar\anaconda3\lib\site-packages (from cryptography>=1.3.4; extra == "secure"->urllib3[secure,socks]~=1.26->selenium) (1.15.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, sniffio, trio, urllib3, h11, wsproto, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
# Successfully installed h11-0.13.0 outcome-1.1.0 selenium-4.1.3 sniffio-1.2.0 trio-0.20.0 trio-websocket-0.9.2 urllib3-1.26.9 wsproto-1.1.0

# %%
import requests
page = requests.get("https://www.gramedia.com/categories/buku")
page
# Out:
# C:\Users\Enggar\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# <Response [200]>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome('chromedriver')

url="https://www.gramedia.com/categories/buku"
driver.get(url)
html = driver.page_source

soup = BeautifulSoup(html, "html.parser")
print(soup.prettify()[:700])
# Out:
# <html class="" lang="id">
#  <head>
#   <base href="/"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#281e5a" name="theme-color"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/assets/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="manifest.json" rel="manifest"/>
#   <link href="/assets/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="z91Vp6ZYo9UoX5D4ur6i4Lrl0l1j3DDoCH08fD3n53g" name="google-site-verification"/>
#   <meta content="810657685650228" property="fb:app_id"/>
#   <style>
#    .async-hide {
#         opacity: 0 !important
#     }
#   </style>
#   <script async="" src="https://cdn.

# %%
soup.find_all('div',{"class":"list-title"})
# Out:
# [<div _ngcontent-web-gramedia-c26="" class="list-title">Dago Love Story: Mentari untuk Dago</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">30 Hari Pintar Membaca Untuk Anak 4-6 Tahun</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Dari Aku Yang Hampir Menyerah</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xi Industri Perhotelan Kur. 13 Ed. Rev</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xi Gambar Teknik Manufaktur 1 Kur. 13 Ed. Rev</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xi Otomatisasi Tata Kelola Humas Dan Keprotokol</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. X Ilmu Gizi Prog Keahlian Kuliner Kur. 13 Ed. R</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Tumbuh Dari Luka;Extended Version</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">01.00</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Top Skor No.1 Cpns &amp; Pppk 2022/2023</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xii Pemeliharaan Sasis Dan Pemindah Tenaga Kend</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Renungan Harian Spirit Junior Aktivitas Edisi Mei 2022</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Dongeng Halo Balita-Penuntun: Menjadi Diri Sendiri (Boardboo</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Penuntun: Ayah, Ibu, Ceritakan Tentang Allah Swt. (Boardbook</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Turning Page</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">If I</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Hukum Dagang Internasional</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Sixtwins : Kembar Enam? Emang Ada?</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Pengantar Ilmu Hukum Dan Aspek Hukum Dalam Ekonomi</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Self-Healing Stories : Bacalah Kisah-Kisah Ini Saat Kau Lela</div>]

# %%
for div_tag in soup.find_all('div',{"class":"list-title"}):
    print(div_tag.get_text())
# Out:
# Dago Love Story: Mentari untuk Dago
# 30 Hari Pintar Membaca Untuk Anak 4-6 Tahun
# Dari Aku Yang Hampir Menyerah
# Smk/Mak Kls. Xi Industri Perhotelan Kur. 13 Ed. Rev
# Smk/Mak Kls. Xi Gambar Teknik Manufaktur 1 Kur. 13 Ed. Rev
# Smk/Mak Kls. Xi Otomatisasi Tata Kelola Humas Dan Keprotokol
# Smk/Mak Kls. X Ilmu Gizi Prog Keahlian Kuliner Kur. 13 Ed. R
# Tumbuh Dari Luka;Extended Version
# 01.00
# Top Skor No.1 Cpns & Pppk 2022/2023
# Smk/Mak Kls. Xii Pemeliharaan Sasis Dan Pemindah Tenaga Kend
# Renungan Harian Spirit Junior Aktivitas Edisi Mei 2022
# Dongeng Halo Balita-Penuntun: Menjadi Diri Sendiri (Boardboo
# Penuntun: Ayah, Ibu, Ceritakan Tentang Allah Swt. (Boardbook
# Turning Page
# If I
# Hukum Dagang Internasional
# Sixtwins : Kembar Enam? Emang Ada?
# Pengantar Ilmu Hukum Dan Aspek Hukum Dalam Ekonomi
# Self-Healing Stories : Bacalah Kisah-Kisah Ini Saat Kau Lela

# %%
import pandas as pd

data = pd.DataFrame()

data['Title'] = [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
data['Author'] = [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
data['Price'] = [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
data['Image'] = [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

links = []
for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
    try:
        links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
    except:
        pass

data['Link'] = links

data
# Out:
#                                                 Title  \
# 0                 Dago Love Story: Mentari untuk Dago
# 1         30 Hari Pintar Membaca Untuk Anak 4-6 Tahun
# 2                       Dari Aku Yang Hampir Menyerah
# 3   Smk/Mak Kls. Xi Industri Perhotelan Kur. 13 Ed...
# 4   Smk/Mak Kls. Xi Gambar Teknik Manufaktur 1 Kur...
# 5   Smk/Mak Kls. Xi Otomatisasi Tata Kelola Humas ...
# 6   Smk/Mak Kls. X Ilmu Gizi Prog Keahlian Kuliner...
# 7                   Tumbuh Dari Luka;Extended Version
# 8                                               01.00
# 9                 Top Skor No.1 Cpns & Pppk 2022/2023
# 10  Smk/Mak Kls. Xii Pemeliharaan Sasis Dan Pemind...
# 11  Renungan Harian Spirit Junior Aktivitas Edisi ...
# 12  Dongeng Halo Balita-Penuntun: Menjadi Diri Sen...
# 13  Penuntun: Ayah, Ibu, Ceritakan Tentang Allah S...
# 14                                       Turning Page
# 15                                               If I
# 16                         Hukum Dagang Internasional
# 17                 Sixtwins : Kembar Enam? Emang Ada?
# 18  Pengantar Ilmu Hukum Dan Aspek Hukum Dalam Eko...
# 19  Self-Healing Stories : Bacalah Kisah-Kisah Ini...
#
#                                                Author       Price  \
# 0                                     SKYSPHIRE None    Rp 99.000
# 1                                        FANNY NOVIA    Rp 48.000
# 2                                      KHOIRUL TRIAN    Rp 79.000
# 3                                       Erna Marlina    Rp 60.000
# 4                                 Yon Fatkhunal Huda    Rp 60.000
# 5                                        TEZAR QOYIM    Rp 60.000
# 6    ANNAYANTI BUDININGSIH, KHALIDA WAHDATULAILI, ...   Rp 66.000
# 7                                     Indra Sugiarto    Rp 99.000
# 8                                   Ameylia Falensia    Rp 95.000
# 9                                 Tim Student Center    Rp 99.500
# 10                                       Parlan None    Rp 56.000
# 11                                        Tim Spirit    Rp 12.000
# 12                                 Laksmi P Manohara    Rp 69.000
# 13                                Beby Haryanti Dewi    Rp 69.000
# 14                                   Auryn Vientania   Rp 110.000
# 15                                      Bella Anjani    Rp 89.000
# 16    Dr. Muhammad Reza Syariffudin Zaki, S.H., M.A.    Rp 95.000
# 17                                       Aanriz None    Rp 99.000
# 18    Dr. Muhammad Reza Syariffudin Zaki, S.H., M.A.   Rp 190.000
# 19                                    Necy Tanudibyo    Rp 68.000
#
#                                                 Image  \
# 0   https://cdn.gramedia.com/uploads/items/Dago_lo...
# 1                  /assets/default-images/product.png
# 2                  /assets/default-images/product.png
# 3                  /assets/default-images/product.png
# 4                  /assets/default-images/product.png
# 5                  /assets/default-images/product.png
# 6                  /assets/default-images/product.png
# 7                  /assets/default-images/product.png
# 8                  /assets/default-images/product.png
# 9                  /assets/default-images/product.png
# 10                 /assets/default-images/product.png
# 11                 /assets/default-images/product.png
# 12                 /assets/default-images/product.png
# 13                 /assets/default-images/product.png
# 14                 /assets/default-images/product.png
# 15                 /assets/default-images/product.png
# 16                 /assets/default-images/product.png
# 17                 /assets/default-images/product.png
# 18                 /assets/default-images/product.png
# 19                 /assets/default-images/product.png
#
#                                                  Link
# 0   https://www.gramedia.com/products/dago-love-st...
# 1   https://www.gramedia.com/products/30-hari-pint...
# 2   https://www.gramedia.com/products/dari-aku-yan...
# 3   https://www.gramedia.com/products/smkmak-kls-x...
# 4   https://www.gramedia.com/products/smkmak-kls-x...
# 5   https://www.gramedia.com/products/smkmak-kls-x...
# 6   https://www.gramedia.com/products/smkmak-kls-x...
# 7   https://www.gramedia.com/products/tumbuh-dari-...
# 8              https://www.gramedia.com/products/0100
# 9   https://www.gramedia.com/products/top-skor-no1...
# 10  https://www.gramedia.com/products/smkmak-kls-x...
# 11  https://www.gramedia.com/products/renungan-har...
# 12  https://www.gramedia.com/products/dongeng-halo...
# 13  https://www.gramedia.com/products/penuntun-aya...
# 14     https://www.gramedia.com/products/turning-page
# 15             https://www.gramedia.com/products/if-i
# 16  https://www.gramedia.com/products/hukum-dagang...
# 17  https://www.gramedia.com/products/sixtwins-kem...
# 18  https://www.gramedia.com/products/pengantar-il...
# 19  https://www.gramedia.com/products/self-healing...

# %%
   title = []
author = []
price = []
image = []
Links = []

driver = webdriver.Chrome('chromedriver')

for i in range(1,21):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    title += [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
    author += [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
    price += [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
    image += [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

    links = []
    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
        except:
            pass
    Links += links

data_multipage = pd.DataFrame()
data_multipage['Title'] = title
data_multipage['Author'] = author
data_multipage['Price'] = price
data_multipage['Image'] = image
data_multipage['Link'] = Links

data_multipage
# Out:
#                                                  Title  \
# 0                  Dago Love Story: Mentari untuk Dago
# 1          30 Hari Pintar Membaca Untuk Anak 4-6 Tahun
# 2                        Dari Aku Yang Hampir Menyerah
# 3    Smk/Mak Kls. Xi Industri Perhotelan Kur. 13 Ed...
# 4    Smk/Mak Kls. Xi Gambar Teknik Manufaktur 1 Kur...
# ..                                                 ...
# 275           Al Qur'an Hafazan 8 Blok Junior Latin A4
# 276  Alquran Cordoba Hafalan Cepat 7 Blok Al Hafidz B7
# 277  Alquran Cordoba Muslimah Auliya Tajwid Tematik A6
# 278  BOX SET Cerita Bergambar Totto-Chan: Gadis Cil...
# 279  Jejak Bung Usmar Biografi Perjuangan Bapak Per...
#
#                                    Author       Price  \
# 0                         SKYSPHIRE None    Rp 99.000
# 1                            FANNY NOVIA    Rp 48.000
# 2                          KHOIRUL TRIAN    Rp 79.000
# 3                           Erna Marlina    Rp 60.000
# 4                     Yon Fatkhunal Huda    Rp 60.000
# ..                                    ...         ...
# 275                            ALQOSBAH    Rp 149.000
# 276   Pt Cordoba International Indonesia    Rp 53.000
# 277   Pt Cordoba International Indonesia    Rp 78.000
# 278                   Tetsuko Kuroyanagi   Rp 168.000
# 279                     Zinggara Hidayat   Rp 400.000
#
#                                                  Image  \
# 0    https://cdn.gramedia.com/uploads/items/Dago_lo...
# 1                   /assets/default-images/product.png
# 2                   /assets/default-images/product.png
# 3                   /assets/default-images/product.png
# 4                   /assets/default-images/product.png
# ..                                                 ...
# 275                 /assets/default-images/product.png
# 276                 /assets/default-images/product.png
# 277                 /assets/default-images/product.png
# 278                 /assets/default-images/product.png
# 279                 /assets/default-images/product.png
#
#                                                   Link
# 0    https://www.gramedia.com/products/dago-love-st...
# 1    https://www.gramedia.com/products/30-hari-pint...
# 2    https://www.gramedia.com/products/dari-aku-yan...
# 3    https://www.gramedia.com/products/smkmak-kls-x...
# 4    https://www.gramedia.com/products/smkmak-kls-x...
# ..                                                 ...
# 275  https://www.gramedia.com/products/al-quran-haf...
# 276  https://www.gramedia.com/products/alquran-cord...
# 277  https://www.gramedia.com/products/alquran-cord...
# 278  https://www.gramedia.com/products/box-set-ceri...
# 279  https://www.gramedia.com/products/jejak-bung-u...
#
# [280 rows x 5 columns]

# %% [markdown]
# coba baca ya :
# - [link 1](https://wwww.dataquest.io/blog/web-scrapin-beautifulsoup/)
# - [link 2](https://github.com/gshreyans/Web-Scraping-Multiple-Pages-/blob/master/IMDB%20Pages%20.ipynb)

# %%
import selenium
from selenium import webdriver
import pandas as pd
from time import sleep

title = []
author = []
price = []
desc = []
num_pages = []
date_issue = []
publisher = []

driver = webdriver.Chrome('chromedriver')

for i in range(1,3):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            link = "https://www.gramedia.com"+tag.find('a',{"_ngcontent-web-gramedia-c26":""})['href']
            driver.get(link)
            html_ind = driver.page_source
            soup_ind = BeautifulSoup(html_ind, "html.parser")

            title.append( soup_ind.find( 'div', {"class":"book-title"} ).get_text() )
            author.append( soup_ind.find('span',{"class":"title-author"}).get_text() )
            price.append( soup_ind.find('div', {'class':'price-product'}).get_text() )
            desc.append( soup_ind.find('pre').get_text() )
            num_pages.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[0].get_text() )
            date_issue.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[2].get_text() )
            publisher.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[1].get_text() )

        except:
            pass

pages = pd.DataFrame()
pages['Title'] = title
pages['Author'] = author
pages['Price'] = price
pages['Desc'] = desc
pages['Num Pages'] = num_pages
pages['Date Issue'] = date_issue
pages['Publisher'] = publisher

pages
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-15c31dab0bf9> in <module>
#      18     driver.get(url)
#      19     html = driver.page_source
# ---> 20     soup = BeautifulSoup(html, "html.parser")
#      21
#      22     for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
#
# NameError: name 'BeautifulSoup' is not defined
