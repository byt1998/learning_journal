# %%
from sympy.tensor.array import derive_by_array
import sympy as sy
import numpy as np

# %% [markdown]
# ## Gradien
#
# ProblemsHacktiv8 DS Curriculum Team1. CarilahGradient darisebuahfungsiberikut: 3𝑥+4𝑦=5

# %%
x,y = sy.symbols('x,y')

# %%
f = 3*x + 4*y -5
f
# Out:
# 3*x + 4*y - 5

# %%
grad = derive_by_array(f, (x,y))
grad
# Out:
# [3, 4]

# %% [markdown]
# # Answer

# %% [markdown]
# fungsi awal 3𝑥+4𝑦=5
# maka diubah menjadi
# y = 5/4 - 3/4x atau y = 1.25 - 0.75x
# x = 5/3 - 5/4y

# %%
y = 1.25 - 0.75*x
x = 5/3 - 5/4*y

# %%
# Define
X = np.linspace(-50,50)

# Define
Y = 1.25 - 0.75*X

result_gradient_x = np.gradient(Y)
result_gradient_x
# Out:
# array([-1.53061224, -1.53061224, -1.53061224, -1.53061224, -1.53061224,
#        -1.53061224, -1.53061224, -1.53061224, -1.53061224, -1.53061224,
#        -1.53061224, -1.53061224, -1.53061224, -1.53061224, -1.53061224,
#        -1.53061224, -1.53061224, -1.53061224, -1.53061224, -1.53061224,
#        -1.53061224, -1.53061224, -1.53061224, -1.53061224, -1.53061224,
#        -1.53061224, -1.53061224, -1.53061224, -1.53061224, -1.53061224,
#        -1.53061224, -1.53061224, -1.53061224, -1.53061224, -1.53061224,
#        -1.53061224, -1.53061224, -1.53061224, -1.53061224, -1.53061224,
#        -1.53061224, -1.53061224, -1.53061224, -1.53061224, -1.53061224,
#        -1.53061224, -1.53061224, -1.53061224, -1.53061224, -1.53061224])

# %%
# Plot `x` and `result_gradient_x`

import matplotlib.pyplot as plt

fig, ax = plt.subplots(ncols=2, figsize=(21,5))

ax[0].plot(X, Y)
ax[0].set_title('Plot of `x`')

ax[1].plot(result_gradient_x, Y)
ax[1].set_title('Plot of `result_gradient_x`')
# Out:
# Text(0.5, 1.0, 'Plot of `result_gradient_x`')

# %%
# Define
Y = np.linspace(-50,50)

# Define
X = (5/3) - (5/4)*Y

result_gradient_y = np.gradient(X)
result_gradient_y
# Out:
# array([-2.55102041, -2.55102041, -2.55102041, -2.55102041, -2.55102041,
#        -2.55102041, -2.55102041, -2.55102041, -2.55102041, -2.55102041,
#        -2.55102041, -2.55102041, -2.55102041, -2.55102041, -2.55102041,
#        -2.55102041, -2.55102041, -2.55102041, -2.55102041, -2.55102041,
#        -2.55102041, -2.55102041, -2.55102041, -2.55102041, -2.55102041,
#        -2.55102041, -2.55102041, -2.55102041, -2.55102041, -2.55102041,
#        -2.55102041, -2.55102041, -2.55102041, -2.55102041, -2.55102041,
#        -2.55102041, -2.55102041, -2.55102041, -2.55102041, -2.55102041,
#        -2.55102041, -2.55102041, -2.55102041, -2.55102041, -2.55102041,
#        -2.55102041, -2.55102041, -2.55102041, -2.55102041, -2.55102041])

# %%
# Plot `x` and `result_gradient_x`

import matplotlib.pyplot as plt

fig, ax = plt.subplots(ncols=2, figsize=(21,5))

ax[0].plot(X, Y)
ax[0].set_title('Plot of `x`')

ax[1].plot(result_gradient_y, X)
ax[1].set_title('Plot of `result_gradient_y`')
# Out:
# Text(0.5, 1.0, 'Plot of `result_gradient_y`')
